# %%
import pandas as pd

# https://stat.gov.pl/obszary-tematyczne/rynek-pracy/pracujacy-zatrudnieni-wynagrodzenia-koszty-pracy/rozklad-wynagrodzen-w-gospodarce-narodowej-w-kwietniu-2025-r-,32,16.html

pd.read_excel("./data/rozklad-wynagrodzen-kwiecien-2025.xlsx")
# Out:
#                                    SPIS TABLIC  \
# 0   ROZKŁAD WYNAGRODZEŃ W GOSPODARCE NARODOWEJ
# 1                                     Tabl. 1.
# 2                                          NaN
# 3                                          NaN
# 4                                     Tabl. 2.
# 5                                          NaN
# 6                                          NaN
# 7                                     Tabl. 3.
# 8                                          NaN
# 9                                          NaN
# 10                                    Tabl. 4.
# 11                                         NaN
# 12                                         NaN
# 13                                    Tabl. 5.
# 14                                         NaN
# 15                                         NaN
# 16                                    Tabl. 6.
# 17                                         NaN
# 18                                         NaN
# ...
