# %%
import utils

utils.caclulate_pension_ranges_2025(100)
# Out:
#      lower_bound  upper_bound  number  percent  women_percentage  \
# 0           0.00        100.0    7613      0.1             69.10
# 1         100.01        200.0    4274      0.1             66.20
# 2         200.01        300.0    3739      0.1             65.90
# 3         300.01        400.0    4917      0.1             55.30
# 4         400.01        500.0    6560      0.0             46.84
# ..           ...          ...     ...      ...               ...
# 96       9600.01       9700.0    8185      0.1             25.70
# 97       9700.01       9800.0    7705      0.1             25.30
# 98       9800.01       9900.0    7455      0.1             24.90
# 99       9900.01      10000.0    7047      0.1             24.60
# 100     10000.01      50000.0  134052      2.1             21.60
#
#      men_percentage  men_number  men_number_cumsum  women_number  \
# 0             30.90      2352.0             2352.0        5260.0
# ...
